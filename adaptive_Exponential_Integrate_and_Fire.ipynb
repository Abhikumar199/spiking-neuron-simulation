# %% [markdown]
# ### Adaptive Exponential Integrate-and-Fire (AdEx) Model
#
# AdEx is a reduced neuron model that captures spike initiation and spike-frequency adaptation using simple differential equations.
